# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Austin = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingsaustin.csv")
Bangkok = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingsbangkok.csv")
Chicago = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingschicago.csv")
Mexico = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingsmexicocity.csv")
Nashville = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingsnashville.csv")
Portland = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingsportland.csv")
Rio = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingsrio.csv")
Toronto = pd.read_csv("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/listingstoronto.csv")

# %%
Austin.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Bangkok.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Chicago.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Mexico.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Nashville.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Portland.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Rio.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Toronto.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
Austin.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                     name  neighbourhood  \
# 0                      *UT/Hyde Park Craftsman Apartment          78705
# 1       Zen-East in the Heart of Austin (monthly rental)          78702
# 2      Eco friendly, Colorful, Clean, Cozy monthly share          78702
# 3              Walk to 6th, Rainey St and Convention Ctr          78702
# 4                                         NW Austin Room          78729
# ...                                                  ...            ...
# 11369                            Cheerful 4 bedroom vila          78735
# 11370  Upscale Riverside 2BR w/ W/D, Gym & Pool, near...          78704
# 11371      Clean, cozy place of your own | 1BR in Austin          78735
# 11372  Downtown Austin - 3BR Presidential - Rooftop Pool          78701
# 11373  Sonder at The Domain | Three-Bedroom Apartment...          78758
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      30.300020 -97.736370  Entire home/apt    102               1
# 1      30.277520 -97.713770  Entire home/apt    179               7
# 2      30.276140 -97.713200     Private room    114              30
# 3      30.260570 -97.734410  Entire home/apt    104               2
# 4      30.456970 -97.784220     Private room     39               1
# ...          ...        ...              ...    ...             ...
# 11369  30.286111 -97.881967  Entire home/apt    413               9
# 11370  30.264778 -97.762131  Entire home/apt    192              31
# 11371  30.247844 -97.845354  Entire home/apt    158              90
# 11372  30.271367 -97.746288  Entire home/apt    299               2
# 11373  30.405400 -97.712830  Entire home/apt    163               2
#
#        number_of_reviews  availability_365
# 0                    232                 0
# 1                     26                 0
# 2                      9                 0
# 3                    578               345
# 4                    264                 0
# ...                  ...               ...
# 11369                  0               362
# 11370                  0               333
# 11371                  0               365
# 11372                  0                26
# 11373                  0               358
#
# [11374 rows x 9 columns]

# %%
Bangkok.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                     name neighbourhood  \
# 0                        Nice room with superb city view   Ratchathewi
# 1                         Easy going landlord,easy place       Bang Na
# 2                      modern-style apartment in Bangkok     Bang Kapi
# 3         Spacious one bedroom at The Kris Condo Bldg. 3     Din Daeng
# 4                                       The escape Condo       Bang Na
# ...                                                  ...           ...
# 17035      Lovely Studio x Silom / Netflix/5min BTS/4pax      Bang Rak
# 17036  Prime embassy access garden view with rooftop ...   Parthum Wan
# 17037    Inviting 360skypool chitlom Centralwld pratunam   Ratchathewi
# 17038                           36楼城市景观/曼谷中心/58平一房一厅高层公寓   Ratchathewi
# 17039   Brand Rental New Condo in Sukhumvit Near BTS/MRT       Vadhana
#
#         latitude   longitude        room_type  price  minimum_nights  \
# 0      13.759830  100.541340  Entire home/apt   1845               3
# 1      13.668180  100.616740     Private room   1275               1
# 2      13.752320  100.624020     Private room    800              60
# 3      13.788230  100.572560     Private room    800               5
# 4      13.673070  100.607680     Private room   1845               1
# ...          ...         ...              ...    ...             ...
# 17035  13.722259  100.519618  Entire home/apt    664               1
# 17036  13.729374  100.545139  Entire home/apt    960              30
# 17037  13.749859  100.543330  Entire home/apt   3500              27
# 17038  13.751557  100.555652  Entire home/apt   1360              28
# 17039  13.740347  100.567159  Entire home/apt   1280               1
#
#        number_of_reviews  availability_365
# 0                     65               362
# 1                      0               358
# 2                      0               364
# 3                      1               278
# 4                      0               365
# ...                  ...               ...
# 17035                  0                84
# 17036                  0               358
# 17037                  0               355
# 17038                  0               358
# 17039                  0               179
#
# [17040 rows x 9 columns]

# %%
Chicago.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                    name    neighbourhood  \
# 0             Hyde Park - Walk to University of Chicago        Hyde Park
# 1                   Tiny Studio Apartment 94 Walk Score        West Town
# 2                                 The Biddle House (#1)     Lincoln Park
# 3                              Lincoln Park Guest House     Lincoln Park
# 4           Luxury in Chicago! 2BR/ 2Ba / Parking / BBQ        West Town
# ...                                                 ...              ...
# 6539    Quaint quiet 1 bedroom unit in Bucktown Chicago        West Town
# 6540       A space that welcomes all with good energy..        West Town
# 6541                      lake and city views entire 2B        Lake View
# 6542                      lake and city views entire 2B        Lake View
# 6543  💥⚡️Amazing Location | Luxury Apt | Rooftop Poo...  Near North Side
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0     41.787900 -87.587800     Private room     95               3
# 1     41.901660 -87.680210  Entire home/apt     65               2
# 2     41.911960 -87.639810  Entire home/apt    127               4
# 3     41.923570 -87.649470     Private room    329               2
# 4     41.897300 -87.658890  Entire home/apt    105             121
# ...         ...        ...              ...    ...             ...
# 6539  41.913940 -87.672440  Entire home/apt     53              32
# 6540  41.907590 -87.688860  Entire home/apt    105               2
# 6541  41.933915 -87.639459  Entire home/apt    150               3
# 6542  41.935920 -87.640590  Entire home/apt    150              32
# 6543  41.896984 -87.628086  Entire home/apt    120               1
#
#       number_of_reviews  availability_365
# 0                   192               355
# 1                   425               165
# 2                    39                98
# 3                     7               179
# 4                     9               365
# ...                 ...               ...
# 6539                  0               358
# 6540                  0                87
# 6541                  0                90
# 6542                  0                83
# 6543                  0               166
#
# [6544 rows x 9 columns]

# %%
Mexico.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                     name  \
# 0                                            Villa Dante
# 1                                      CONDESA HAUS  B&B
# 2                   Great space in historical San Rafael
# 3      Spacious Clean Quiet room (own bath) in la Con...
# 4                      2 bedroom apt. deco bldg, Condesa
# ...                                                  ...
# 19650                          Roma Norte cozy apartment
# 19651      Amazing apartment in the best area of Polanco
# 19652  Loft Tecamachalco 500m de Palmas Lomas Chapult...
# 19653  Cuarto Privado Mediano -PH Compartido, Lomas CDMX
# 19654  Cómoda habitación con dos camas individuales m...
#
#                neighbourhood   latitude  longitude        room_type  price  \
# 0      Cuajimalpa de Morelos  19.382830 -99.271780  Entire home/apt   4123
# 1                 Cuauhtémoc  19.411620 -99.177940  Entire home/apt  15000
# 2                 Cuauhtémoc  19.439770 -99.156050  Entire home/apt    600
# 3                 Cuauhtémoc  19.410830 -99.180570     Private room   1237
# 4                 Cuauhtémoc  19.411520 -99.168570  Entire home/apt   1959
# ...                      ...        ...        ...              ...    ...
# 19650             Cuauhtémoc  19.414141 -99.164360  Entire home/apt    905
# 19651         Miguel Hidalgo  19.429930 -99.185967  Entire home/apt   1520
# 19652         Miguel Hidalgo  19.429134 -99.226526     Private room    480
# 19653         Miguel Hidalgo  19.419214 -99.233233     Private room    339
# 19654               Coyoacán  19.343215 -99.148787     Private room    200
#
#        minimum_nights  number_of_reviews  availability_365
# 0                   1                  0               363
# 1                   1                 50               344
# 2                   2                 66               364
# 3                   2                 53               178
# 4                   4                 39               332
# ...               ...                ...               ...
# 19650               1                  1               341
# 19651               2                  0               362
# 19652               7                  0               328
# 19653               1                  0               180
# 19654               1                  0               364
#
# [19655 rows x 9 columns]

# %%
Nashville.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                    name neighbourhood  \
# 0                                       Nashville Charm    District 6
# 1                                 Close to Vanderbilt 2   District 18
# 2     Vandy/Belmont/10 mins to Broadway - Sunny 800 ...   District 18
# 3               ButterflyRoom-private bath- open in oct   District 12
# 4             MorningstarHouse, monthly room- open sept   District 12
# ...                                                 ...           ...
# 6355                   TWO LUXURY TOWNHOMES - SLEEPS 24   District 21
# 6356  NYE Buffett Style! Margaritaville Studio Sleeps 4   District 19
# 6357  Good as Gold Rowhouse - Minutes to downtown, V...   District 18
# 6358    New Year's Eve!! Margaritaville Studio Sleeps 4   District 19
# 6359  Nashville Famous - Luxurious Townhome with Swe...    District 8
#
#        latitude  longitude        room_type  price  minimum_nights  \
# 0     36.173150 -86.735810     Private room     40              30
# 1     36.125230 -86.812780     Private room     60               1
# 2     36.131220 -86.800660  Entire home/apt     81               2
# 3     36.162490 -86.589880     Private room     36              30
# 4     36.161020 -86.592070     Private room     34              30
# ...         ...        ...              ...    ...             ...
# 6355  36.153390 -86.821220  Entire home/apt    522               1
# 6356  36.156194 -86.776269  Entire home/apt    339               2
# 6357  36.136728 -86.798335  Entire home/apt    263               3
# 6358  36.156654 -86.776814  Entire home/apt    339               2
# 6359  36.243920 -86.736860  Entire home/apt    156               1
#
#       number_of_reviews  availability_365
# 0                   674               199
# 1                   267               233
# 2                   607                30
# 3                    96               354
# 4                    76               354
# ...                 ...               ...
# 6355                  0               313
# 6356                  0                 4
# 6357                  0                84
# 6358                  0                 3
# 6359                  0               356
#
# [6360 rows x 9 columns]

# %%
Portland.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                    name       neighbourhood  \
# 0     Alberta Arts 2 bedroom suite, charming 1906 house           Concordia
# 1                   Mt. Hood View in the Pearl District               Pearl
# 2                   Grandpa's Bunkhouse-Backyard Studio             Roseway
# 3         Auntie's Hideaway--Daylight Downstairs Studio             Roseway
# 4                                Perfect Portland Place        Goose Hollow
# ...                                                 ...                 ...
# 3729           Everything you need | Studio in Portland  Northwest District
# 3730                 Relax in comfort | 1BR in Portland            Hayhurst
# 3731      The Câlin & Magnifique Suite ~ NW 23rd Wonder  Northwest District
# 3732      Modern 2 BR Home Walkable to Alberta and more                King
# 3733  Modern Stylish Apt in Alphabet District / Slab...  Northwest District
#
#        latitude   longitude        room_type  price  minimum_nights  \
# 0     45.564880 -122.634180  Entire home/apt     89               3
# 1     45.525640 -122.682730  Entire home/apt    140              30
# 2     45.548040 -122.585410  Entire home/apt    129               3
# 3     45.547930 -122.583580  Entire home/apt    133               3
# 4     45.522580 -122.699550  Entire home/apt    104              30
# ...         ...         ...              ...    ...             ...
# 3729  45.531189 -122.690158  Entire home/apt    154             120
# 3730  45.484074 -122.747648  Entire home/apt    173             365
# 3731  45.534796 -122.697880  Entire home/apt    234               1
# 3732  45.561982 -122.661731  Entire home/apt     87               2
# 3733  45.532956 -122.690237  Entire home/apt    182               2
#
#       number_of_reviews  availability_365
# 0                   591               353
# 1                   127               365
# 2                   243               365
# 3                   206               358
# 4                    15               235
# ...                 ...               ...
# 3729                  0               365
# 3730                  0               365
# 3731                  0               319
# 3732                  0               354
# 3733                  0               269
#
# [3734 rows x 9 columns]

# %%
Rio.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                     name neighbourhood  \
# 0      Very Nice 2Br in Copacabana w. balcony, fast WiFi    Copacabana
# 1       Nice and cozy near Ipanema Beach, w/ home office       Ipanema
# 2              Beautiful Modern Decorated Studio in Copa    Copacabana
# 3                       Cosy flat close to Ipanema beach       Ipanema
# 4         COPACABANA SEA BREEZE  -  RIO - 20 X Superhost    Copacabana
# ...                                                  ...           ...
# 24544                             COPACABANA FAMILY HOME    Copacabana
# 24545    Stunning & Luxurious Apartment in Flamengo (#2)      Flamengo
# 24546                   Apartamento aconchegante no Leme          Leme
# 24547  Apto 520 na Quadra da Praia de Copacabana Posto 3    Copacabana
# 24548    Villa overlooking Pedra da Gávea in São Conrado   São Conrado
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0     -22.965990 -43.179400  Entire home/apt    350               5
# 1     -22.984050 -43.201890  Entire home/apt    296               3
# 2     -22.977350 -43.191050  Entire home/apt    387               3
# 3     -22.988390 -43.192320  Entire home/apt    172               2
# 4     -22.981070 -43.191360  Entire home/apt    260               3
# ...          ...        ...              ...    ...             ...
# 24544 -22.977974 -43.190044  Entire home/apt   1786               4
# 24545 -22.932098 -43.177090  Entire home/apt    460               2
# 24546 -22.962902 -43.170973  Entire home/apt    891               2
# 24547 -22.968714 -43.183293  Entire home/apt    177               4
# 24548 -22.994539 -43.258093  Entire home/apt    818               1
#
#        number_of_reviews  availability_365
# 0                    267               257
# 1                     85               107
# 2                    238               206
# 3                    181               207
# 4                    378                58
# ...                  ...               ...
# 24544                  0               365
# 24545                  1                 3
# 24546                  0               267
# 24547                  0                81
# 24548                  0               304
#
# [24549 rows x 9 columns]

# %%
Toronto.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews_ltm', 
            'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'license'],axis=1)
# Out:
#                                                    name  \
# 0                       Beautiful home in amazing area!
# 1                    Downtown Harbourfront Private Room
# 2                       Queen Bedroom close to downtown
# 3           Executive Studio Unit- Ideal for One Person
# 4                    Downtown Toronto - Waterview Condo
# ...                                                 ...
# 15256        "The Red" Downtown Toronto 5 Star Location
# 15257  Dragon Ball Inspired Super Cozy Studio Apartment
# 15258             Super North York Location Near Seneca
# 15259               Big Private Room in Midtown Toronto
# 15260               2 Bedroom condo King bed Gym & Pool
#
#                            neighbourhood   latitude  longitude  \
# 0                        Little Portugal  43.645900 -79.424230
# 1      Waterfront Communities-The Island  43.640800 -79.376730
# 2                   Briar Hill-Belgravia  43.698050 -79.454110
# 3                        South Riverdale  43.668840 -79.327250
# 4      Waterfront Communities-The Island  43.640150 -79.376250
# ...                                  ...        ...        ...
# 15256               Kensington-Chinatown  43.651695 -79.399825
# 15257               Kensington-Chinatown  43.651729 -79.400658
# 15258                 Don Valley Village  43.783640 -79.350740
# 15259                Mount Pleasant West  43.697744 -79.391323
# 15260                  Banbury-Don Mills  43.719692 -79.350359
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0      Entire home/apt    469              28                  7
# 1         Private room     96             180                169
# 2         Private room     72              28                217
# 3      Entire home/apt     45             365                 26
# 4      Entire home/apt    128             180                  1
# ...                ...    ...             ...                ...
# 15256     Private room     40               7                  0
# 15257  Entire home/apt     59               2                  0
# 15258     Private room     35              28                  0
# 15259     Private room     36              28                  0
# 15260  Entire home/apt    120              28                  0
#
#        availability_365
# 0                     0
# 1                   365
# 2                   365
# 3                   280
# 4                   365
# ...                 ...
# 15256                78
# 15257                62
# 15258               365
# 15259               365
# 15260               166
#
# [15261 rows x 9 columns]

# %%
AirbnbCities = pd.merge('Austin', 'Bangkok', 'Chicago', 'Mexico', 'Nashville', 'Portland', 'Rio', 'Toronto')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2b2bd14aeecd> in <module>
# ----> 1 AirbnbCities = pd.merge('Austin', 'Bangkok', 'Chicago', 'Mexico', 'Nashville', 'Portland', 'Rio', 'Toronto')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     596         validate=None,
#     597     ):
# --> 598         _left = _validate_operand(left)
#     599         _right = _validate_operand(right)
#     600         self.left = self.orig_left = _left
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2146             return obj.to_frame()
#    2147     else:
# -> 2148         raise TypeError(
#    2149             f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2150         )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'str'> was passed

# %%
AustinMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/austin.png")
BangkokMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/bangkok.png")
ChicagoMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/chicago.png")
MexicoMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/mexicocity.png")
NashvilleMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/nashville.png")
PortlandMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/portland.png")
RioMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/rio.png")
TorontoMap = plt.imread("C:/Users/vanch/Desktop/Entity/DSO110/Reina's Wrangled Cities/toronto.png")

# %%
BBoxA = (Austin.longitude.min(), Austin.longitude.max(), Austin.latitude.min(), Austin.latitude.max())
BBoxB = (Bangkok.longitude.min(), Bangkok.longitude.max(), Bangkok.latitude.min(), Bangkok.latitude.max())
BBoxC = (Chicago.longitude.min(), Chicago.longitude.max(), Chicago.latitude.min(), Chicago.latitude.max())
BBoxM = (Mexico.longitude.min(), Mexico.longitude.max(), Mexico.latitude.min(), Mexico.latitude.max())
BBoxN = (Nashville.longitude.min(), Nashville.longitude.max(), Nashville.latitude.min(), Nashville.latitude.max())
BBoxP = (Portland.longitude.min(), Portland.longitude.max(), Portland.latitude.min(), Portland.latitude.max())
BBoxR = (Rio.longitude.min(), Rio.longitude.max(), Rio.latitude.min(), Rio.latitude.max())
BBoxT = (Toronto.longitude.min(), Toronto.longitude.max(), Toronto.latitude.min(), Toronto.latitude.max())

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Austin.longitude, Austin.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Austin Airbnb Rentals')
ax.set_xlim(BBoxA[0],BBoxA[1])
ax.set_ylim(BBoxA[2],BBoxA[3])
ax.imshow(AustinMap, zorder=0, extent = BBoxA, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Bangkok.longitude, Bangkok.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Bangkok Airbnb Rentals')
ax.set_xlim(BBoxB[0],BBoxB[1])
ax.set_ylim(BBoxB[2],BBoxB[3])
ax.imshow(BangkokMap, zorder=0, extent = BBoxB, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Chicago.longitude, Chicago.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Chicago Airbnb Rentals')
ax.set_xlim(BBoxC[0],BBoxC[1])
ax.set_ylim(BBoxC[2],BBoxC[3])
ax.imshow(ChicagoMap, zorder=0, extent = BBoxC, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Mexico.longitude, Mexico.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Mexico Airbnb Rentals')
ax.set_xlim(BBoxM[0],BBoxM[1])
ax.set_ylim(BBoxM[2],BBoxM[3])
ax.imshow(MexicoMap, zorder=0, extent = BBoxM, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Nashville.longitude, Nashville.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Nashville Airbnb Rentals')
ax.set_xlim(BBoxN[0],BBoxN[1])
ax.set_ylim(BBoxN[2],BBoxN[3])
ax.imshow(NashvilleMap, zorder=0, extent = BBoxN, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Portland.longitude, Portland.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Portland Airbnb Rentals')
ax.set_xlim(BBoxP[0],BBoxP[1])
ax.set_ylim(BBoxP[2],BBoxP[3])
ax.imshow(PortlandMap, zorder=0, extent = BBoxP, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Rio.longitude, Rio.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Rio Airbnb Rentals')
ax.set_xlim(BBoxR[0],BBoxR[1])
ax.set_ylim(BBoxR[2],BBoxR[3])
ax.imshow(RioMap, zorder=0, extent = BBoxR, aspect= 'equal')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(Toronto.longitude, Toronto.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Toronto Airbnb Rentals')
ax.set_xlim(BBoxT[0],BBoxT[1])
ax.set_ylim(BBoxT[2],BBoxT[3])
ax.imshow(TorontoMap, zorder=0, extent = BBoxT, aspect= 'equal')
